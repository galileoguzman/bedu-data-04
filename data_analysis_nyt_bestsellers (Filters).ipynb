# %%
# Importing data
import pandas as pd

# Dataframe preparation
FILENAME = 'datasets/new_york_times_bestsellers.csv'

# Data frame reading
df = pd.read_csv(FILENAME)
df.head()
# Out:
#    Unnamed: 0                                 amazon_product_url  \
# 0           0  http://www.amazon.com/The-Host-Novel-Stephenie...
# 1           1  http://www.amazon.com/Love-Youre-With-Emily-Gi...
# 2           2  http://www.amazon.com/The-Front-Garano-Patrici...
# 3           3  http://www.amazon.com/Snuff-Chuck-Palahniuk/dp...
# 4           5  http://www.amazon.com/Phantom-Prey-John-Sandfo...
#
#               author                                        description  \
# 0    Stephenie Meyer  Descr: Aliens have taken control of the minds ...
# 1       Emily Giffin  Descr: A woman's happy marriage is shaken when...
# 2  Patricia Cornwell  Descr: A Massachusetts state investigator and ...
# 3    Chuck Palahniuk  Descr: An aging porn queens aims to cap her ca...
# 4      John Sandford  Descr: The Minneapolis detective Lucas Davenpo...
#
#        publisher                     title                       oid  \
# ...

# %%
df['author'].str.startswith('R')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2261    False
# 2262    False
# 2263    False
# 2264    False
# 2265    False
# Name: author, Length: 2266, dtype: bool

# %%
df[df['author'].str.startswith('R')].head()
# Out:
#      Unnamed: 0                                 amazon_product_url  \
# 60           79  http://www.amazon.com/Chasing-Darkness-Elvis-N...
# 73           94  http://www.amazon.com/Chasing-Darkness-Elvis-N...
# 85          110  http://www.amazon.com/Killer-View-Fleming-Ridl...
# 109         143  http://www.amazon.com/Foreign-Body-Robin-Cook/...
# 121         158  http://www.amazon.com/Foreign-Body-Robin-Cook/...
#
#              author                                        description  \
# 60     Robert Crais  Descr: he Los Angeles private eye Elvis Cole r...
# 73     Robert Crais  Descr: Is the Los Angeles private eye Elvis Co...
# 85   Ridley Pearson  Descr: A sheriff in Sun Valley, Idaho, investi...
# 109      Robin Cook  Descr: A medical student investigates a rising...
# 121      Robin Cook  Descr: A medical student investigates a rising...
#
#             publisher             title                       oid  \
# ...

# %%
books_pricing_greater_than_20 = df['price.numberDouble'] > 20
books_pricing_less_than_25 = df['price.numberDouble'] < 25

# %%
df[books_pricing_greater_than_20].head()
# Out:
#    Unnamed: 0                                 amazon_product_url  \
# 0           0  http://www.amazon.com/The-Host-Novel-Stephenie...
# 1           1  http://www.amazon.com/Love-Youre-With-Emily-Gi...
# 2           2  http://www.amazon.com/The-Front-Garano-Patrici...
# 3           3  http://www.amazon.com/Snuff-Chuck-Palahniuk/dp...
# 4           5  http://www.amazon.com/Phantom-Prey-John-Sandfo...
#
#               author                                        description  \
# 0    Stephenie Meyer  Descr: Aliens have taken control of the minds ...
# 1       Emily Giffin  Descr: A woman's happy marriage is shaken when...
# 2  Patricia Cornwell  Descr: A Massachusetts state investigator and ...
# 3    Chuck Palahniuk  Descr: An aging porn queens aims to cap her ca...
# 4      John Sandford  Descr: The Minneapolis detective Lucas Davenpo...
#
#        publisher                     title                       oid  \
# ...

# %%
df[books_pricing_greater_than_20]
# Out:
#       Unnamed: 0                                 amazon_product_url  \
# 0              0  http://www.amazon.com/The-Host-Novel-Stephenie...
# 1              1  http://www.amazon.com/Love-Youre-With-Emily-Gi...
# 2              2  http://www.amazon.com/The-Front-Garano-Patrici...
# 3              3  http://www.amazon.com/Snuff-Chuck-Palahniuk/dp...
# 4              5  http://www.amazon.com/Phantom-Prey-John-Sandfo...
# ...          ...                                                ...
# 2261        3027  http://www.amazon.com/Unintended-Consequences-...
# 2262        3028  http://www.amazon.com/Six-Years-Harlan-Coben/d...
# 2263        3029  http://www.amazon.com/The-Interestings-Novel-M...
# 2264        3030  http://www.amazon.com/Man-Without-Breath-Berni...
# 2265        3031  http://www.amazon.com/The-Storyteller-Jodi-Pic...
#
#                  author                                        description  \
# ...

# %%
books_ranking_one = df['rank.numberInt'] == '1'

# %%
df[books_ranking_one].head()
# Out:
#     Unnamed: 0                                 amazon_product_url  \
# 39          51  http://www.amazon.com/Fearless-Fourteen-Janet-...
# 47          63  http://www.amazon.com/Fearless-Fourteen-Janet-...
# 66          85  http://www.amazon.com/Tribute-Nora-Roberts/dp/...
# 76          98  http://www.amazon.com/Tribute-Nora-Roberts/dp/...
# 86         111  http://www.amazon.com/Secret-Servant-Gabriel-A...
#
#              author                                        description  \
# 39  Janet Evanovich  Descr: Stephanie Plum and her boyfriend Joe Mo...
# 47  Janet Evanovich  Descr: Stephanie Plum and her boyfriend Joe Mo...
# 66     Nora Roberts  Descr: A former child star returns to Virginia...
# 76     Nora Roberts  Descr: A former child star returns to Virginia...
# 86     Daniel Silva  Descr: Gabriel Allon, an art restorer and an o...
#
#        publisher               title                       oid  \
# 39  St. Martin’s   FEARLESS FOURTEEN  5b4aa4ead3089013507db1db
# ...

# %%
df[books_pricing_greater_than_20 & books_pricing_less_than_25 & books_ranking_one].head()
# Out:
#      Unnamed: 0                                 amazon_product_url  \
# 103         136  http://www.amazon.com/Acheron-Dark-Hunter-Book...
# 146         189  http://www.amazon.com/Dark-Curse-Carpathian-Ch...
# 179         231  http://www.amazon.com/The-Lucky-One-Nicholas-S...
# 192         245  http://www.amazon.com/The-Lucky-One-Nicholas-S...
# 585         776  http://www.amazon.com/Bad-Moon-Rising-Dark-Hun...
#
#                author                                        description  \
# 103  Sherrilyn Kenyon  Descr: Book 12 of the Dark-Hunter paranormal s...
# 146  Christine Feehan  Descr: Lara Callandine, an expert in the field...
# 179   Nicholas Sparks  Descr: A marine returning home sets out to fin...
# 192   Nicholas Sparks  Descr: A marine returning home sets out to tra...
# 585  Sherrilyn Kenyon  Descr: Book 18 of the Dark-Hunter paranormal s...
#
#          publisher            title                       oid  \
# ...
